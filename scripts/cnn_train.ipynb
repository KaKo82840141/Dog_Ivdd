# %%
# -*- coding: utf-8 -*-
import os, re, datetime, itertools, math
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

# =========================
# パス設定（必要に応じて変更）
# =========================
# あなたのリポジトリ構成に合わせた既定値
PROCESS_DIR = r"C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\process"

# 使いたい軌跡サブフォルダ（例：正規化図のみ使うなら *_nor を指定）
# 例) ["tail_set_nor", "left_paw_nor", "right_paw_nor"]
# 例) 生の軌跡なら ["tail_set", "left_paw", "right_paw"]
SRC_SUBDIRS = [ 
    "left_paw_nor", 
    # "left_tarsal_nor", 
    "right_paw_nor", 
    # "right_tarsal_nor"
    ]  # ←必要に応じて変更

# 出力先
MODEL_DIR = r"C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj"
CURVE_DIR = r"C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\output\learning_curve_traj"
EVAL_DIR  = r"C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\output\learning_curve_traj"
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(CURVE_DIR, exist_ok=True)
os.makedirs(EVAL_DIR,  exist_ok=True)

# =========================
# ハイパパラメータ
# =========================
IMG_SIZE = (300, 300)
BATCH_SIZE = 16
EPOCHS = 200
VAL_RATIO = 0.15
LEARNING_RATE = 5e-6
AUGMENT = True  # 軽いDataAugを入れる場合は True

# =========================
# ラベル推定（ファイル名/親フォルダ名から）
# =========================
CLASSES = ["normal", "ivdd"]  # 0: normal, 1: ivdd
NAME2IDX = {"normal": 0, "ivdd": 1}

def infer_label_from_path(p: Path):
    """
    one / two / ivdd -> ivdd, normal -> normal
    ファイル名と親フォルダ名をトークン化して判定
    """
    def tokens(s):
        return [t for t in re.split(r"[^a-z0-9]+", s.lower()) if t]

    all_tokens = set(tokens(p.stem)) | set(tokens(p.name)) | set(tokens(p.parent.name))
    if ("normal" in all_tokens):
        return NAME2IDX["normal"]
    if ("ivdd" in all_tokens) or ("one" in all_tokens) or ("two" in all_tokens):
        return NAME2IDX["ivdd"]
    return None  # 判定不能

# =========================
# 画像リスト収集
# =========================
def collect_images(process_dir: str, subdirs=None, exts=(".png", ".jpg", ".jpeg")):
    proc = Path(process_dir)
    paths, labels = [], []
    subdirs = list(subdirs) if subdirs else []

    if subdirs:
        cand_dirs = [proc / sd for sd in subdirs]
    else:
        # subdirs未指定なら process 直下のディレクトリすべて
        cand_dirs = [d for d in proc.iterdir() if d.is_dir()]

    for d in cand_dirs:
        if not d.exists():
            print(f"[WARN] ディレクトリが見つかりません: {d}")
            continue
        for p in d.rglob("*"):
            if p.is_file() and p.suffix.lower() in exts:
                y = infer_label_from_path(p)
                if y is None:
                    print(f"[SKIP] ラベル不明: {p}")
                    continue
                paths.append(str(p))
                labels.append(y)

    if not paths:
        raise FileNotFoundError("画像が見つかりませんでした。SRC_SUBDIRS とファイル名ルール（one/two/ivdd/normal）を確認してください。")

    df = pd.DataFrame({"path": paths, "y": labels})
    return df

df_all = collect_images(PROCESS_DIR, SRC_SUBDIRS)
print("[INFO] 収集画像数:", len(df_all))
print(df_all["y"].value_counts().rename(index={0:"normal",1:"ivdd"}))

# =========================
# Stratified Train/Val 分割
# =========================
sss = StratifiedShuffleSplit(n_splits=1, test_size=VAL_RATIO, random_state=42)
train_idx, val_idx = next(sss.split(df_all["path"], df_all["y"]))
df_tr = df_all.iloc[train_idx].reset_index(drop=True)
df_va = df_all.iloc[val_idx].reset_index(drop=True)
print(f"[INFO] split -> train: {len(df_tr)}, val: {len(df_va)}")

# =========================
# tf.data パイプライン
# =========================
AUTOTUNE = tf.data.AUTOTUNE

def decode_img(path):
    img_bytes = tf.io.read_file(path)
    # PNG/JPEG いずれも3chでデコード
    img = tf.io.decode_image(img_bytes, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.clip_by_value(img/255.0, 0.0, 1.0)
    return img

def aug(img):
    # 軽いDataAug（必要に応じて調整）
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, max_delta=0.05)
    img = tf.image.random_contrast(img, lower=0.9, upper=1.1)
    return img

def make_ds(paths, labels, training=True, batch_size=BATCH_SIZE):
    ds_paths = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(path, y):
        img = decode_img(path)
        if training and AUGMENT:
            img = aug(img)
        y_onehot = tf.one_hot(y, depth=len(CLASSES))
        return img, y_onehot
    ds = ds_paths.map(_load, num_parallel_calls=AUTOTUNE)
    if training:
        ds = ds.shuffle(buffer_size=min(1000, len(paths)))
    ds = ds.batch(batch_size).prefetch(AUTOTUNE)
    return ds

train_ds = make_ds(df_tr["path"].values, df_tr["y"].values, training=True)
val_ds   = make_ds(df_va["path"].values, df_va["y"].values, training=False)

# =========================
# class_weight（不均衡対策）
# =========================
cls_w = compute_class_weight(
    class_weight="balanced",
    classes=np.array([0,1]),
    y=df_tr["y"].values
)
class_weight = {0: float(cls_w[0]), 1: float(cls_w[1])}
print("[INFO] class_weight:", class_weight)

# =========================
# CNN モデル（提示の構成を踏襲）
# =========================
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(2, activation='softmax')  # 2クラス
])
model.compile(optimizer=Adam(learning_rate=LEARNING_RATE),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

# =========================
#  学習
# =========================
now = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
model_path = os.path.join(MODEL_DIR, f"traj_cnn_{now}.h5")
curve_path = os.path.join(CURVE_DIR, f"traj_learning_curve_{now}.png")
pred_csv   = os.path.join(EVAL_DIR,  f"traj_val_predictions_{now}.csv")
cm_png     = os.path.join(EVAL_DIR,  f"traj_cm_{now}.png")

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", mode="min", factor=0.5, patience=5, min_lr=1e-6, verbose=1
    ),
    tf.keras.callbacks.ModelCheckpoint(
        model_path, monitor="val_accuracy", mode="max", save_best_only=True, verbose=1
    )
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    class_weight=class_weight,
    verbose=1,
    callbacks=callbacks
)

print(f"✅ モデル保存: {model_path}")

# =========================
# 学習曲線保存
# =========================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss"); plt.legend(); plt.grid(True)

plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy"); plt.legend(); plt.grid(True)

plt.tight_layout()
plt.savefig(curve_path, dpi=150)
plt.close()
print(f"✅ 学習曲線保存: {curve_path}")

# =========================
#  検証データでの詳細評価（CSV & 混同行列）
# =========================
# バッチ毎に path を持ち回すため簡便に numpy で回す
val_paths = df_va["path"].values
val_labels = df_va["y"].values
y_true = []
y_prob = []
y_pred = []

for start in range(0, len(val_paths), BATCH_SIZE):
    batch_paths = val_paths[start:start+BATCH_SIZE]
    batch_imgs = np.stack([tf.image.resize(tf.io.decode_image(tf.io.read_file(p), channels=3, expand_animations=False), IMG_SIZE).numpy()/255.0
                           for p in batch_paths], axis=0)
    probs = model.predict(batch_imgs, verbose=0)
    preds = probs.argmax(axis=1)
    y_prob.append(probs)
    y_pred.append(preds)
    y_true.append(val_labels[start:start+BATCH_SIZE])

y_true = np.concatenate(y_true)
y_pred = np.concatenate(y_pred)
y_prob = np.concatenate(y_prob)

print("\n[Validation] classification_report")
print(classification_report(y_true, y_pred, target_names=CLASSES, digits=4))

# 予測CSV
df_pred = pd.DataFrame({
    "path": val_paths,
    "true": [CLASSES[i] for i in y_true],
    "pred": [CLASSES[i] for i in y_pred],
    "p_normal": y_prob[:, 0],
    "p_ivdd": y_prob[:, 1],
})
df_pred.to_csv(pred_csv, index=False, encoding="utf-8-sig")
print(f"✅ 予測CSV保存: {pred_csv}")

# 混同行列PNG
cm = confusion_matrix(y_true, y_pred, labels=[0,1])
fig, ax = plt.subplots(figsize=(6,6))
im = ax.imshow(cm.astype(np.float32) / max(cm.sum(),1), cmap="Blues")
ax.figure.colorbar(im, ax=ax)
ax.set_xticks([0,1]); ax.set_yticks([0,1])
ax.set_xticklabels(CLASSES); ax.set_yticklabels(CLASSES)
ax.set_xlabel("Predicted"); ax.set_ylabel("True")
ax.set_title("Confusion Matrix (Validation)")
for i in range(2):
    for j in range(2):
        ax.text(j, i, int(cm[i,j]),
                ha="center",
                color="white" if cm[i,j] > cm.max()/2 else "black",
                fontsize=14)
plt.tight_layout()
plt.savefig(cm_png, dpi=150); plt.close()
print(f"✅ 混同行列保存: {cm_png}")
# Out:
# [INFO] 収集画像数: 2422
# y
# normal    1494
# ivdd       928
# Name: count, dtype: int64
# [INFO] split -> train: 2058, val: 364
# [INFO] class_weight: {0: 0.8108747044917257, 1: 1.3041825095057034}
# c:\kanno\envs\MLya\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 298, 298, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 149, 149, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 147, 147, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 73, 73, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 71, 71, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 35, 35, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_8 (Flatten)             │ (None, 156800)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │    20,070,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,164,034 (76.92 MB)
#  Trainable params: 20,164,034 (76.92 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4816 - loss: 0.7120
# Epoch 1: val_accuracy improved from -inf to 0.61813, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 27s 177ms/step - accuracy: 0.4818 - loss: 0.7119 - val_accuracy: 0.6181 - val_loss: 0.6838 - learning_rate: 5.0000e-06
# Epoch 2/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.5165 - loss: 0.6938
# Epoch 2: val_accuracy did not improve from 0.61813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.5163 - loss: 0.6938 - val_accuracy: 0.3819 - val_loss: 0.6973 - learning_rate: 5.0000e-06
# Epoch 3/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5581 - loss: 0.6920
# Epoch 3: val_accuracy did not improve from 0.61813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.5581 - loss: 0.6920 - val_accuracy: 0.3819 - val_loss: 0.6947 - learning_rate: 5.0000e-06
# Epoch 4/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5218 - loss: 0.6895
# Epoch 4: val_accuracy did not improve from 0.61813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.5220 - loss: 0.6895 - val_accuracy: 0.3819 - val_loss: 0.6933 - learning_rate: 5.0000e-06
# Epoch 5/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4779 - loss: 0.6895
# Epoch 5: val_accuracy did not improve from 0.61813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.4780 - loss: 0.6895 - val_accuracy: 0.6181 - val_loss: 0.6810 - learning_rate: 5.0000e-06
# Epoch 6/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5579 - loss: 0.6917
# Epoch 6: val_accuracy did not improve from 0.61813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.5578 - loss: 0.6917 - val_accuracy: 0.6181 - val_loss: 0.6800 - learning_rate: 5.0000e-06
# Epoch 7/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5704 - loss: 0.6883
# Epoch 7: val_accuracy improved from 0.61813 to 0.63187, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.5704 - loss: 0.6883 - val_accuracy: 0.6319 - val_loss: 0.6802 - learning_rate: 5.0000e-06
# Epoch 8/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5431 - loss: 0.6946
# Epoch 8: val_accuracy did not improve from 0.63187
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.5431 - loss: 0.6946 - val_accuracy: 0.6181 - val_loss: 0.6823 - learning_rate: 5.0000e-06
# Epoch 9/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6252 - loss: 0.6866
# Epoch 9: val_accuracy did not improve from 0.63187
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.6251 - loss: 0.6866 - val_accuracy: 0.6264 - val_loss: 0.6803 - learning_rate: 5.0000e-06
# Epoch 10/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5700 - loss: 0.6842
# Epoch 10: val_accuracy did not improve from 0.63187
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.5699 - loss: 0.6842 - val_accuracy: 0.6181 - val_loss: 0.6675 - learning_rate: 5.0000e-06
# Epoch 11/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5594 - loss: 0.6905
# Epoch 11: val_accuracy improved from 0.63187 to 0.70055, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.5595 - loss: 0.6905 - val_accuracy: 0.7005 - val_loss: 0.6684 - learning_rate: 5.0000e-06
# Epoch 12/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6258 - loss: 0.6755
# Epoch 12: val_accuracy improved from 0.70055 to 0.84066, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.6257 - loss: 0.6755 - val_accuracy: 0.8407 - val_loss: 0.6679 - learning_rate: 5.0000e-06
# Epoch 13/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6710 - loss: 0.6661
# Epoch 13: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.6708 - loss: 0.6662 - val_accuracy: 0.7170 - val_loss: 0.6693 - learning_rate: 5.0000e-06
# Epoch 14/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6789 - loss: 0.6598
# Epoch 14: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.6786 - loss: 0.6598 - val_accuracy: 0.7115 - val_loss: 0.6475 - learning_rate: 5.0000e-06
# Epoch 15/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6364 - loss: 0.6637
# Epoch 15: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.6365 - loss: 0.6636 - val_accuracy: 0.6648 - val_loss: 0.6341 - learning_rate: 5.0000e-06
# Epoch 16/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.6692 - loss: 0.6553
# Epoch 16: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.6693 - loss: 0.6553 - val_accuracy: 0.7555 - val_loss: 0.6309 - learning_rate: 5.0000e-06
# Epoch 17/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7205 - loss: 0.6404
# Epoch 17: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.7204 - loss: 0.6404 - val_accuracy: 0.6731 - val_loss: 0.6480 - learning_rate: 5.0000e-06
# Epoch 18/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6651 - loss: 0.6404
# Epoch 18: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.6653 - loss: 0.6404 - val_accuracy: 0.8104 - val_loss: 0.6162 - learning_rate: 5.0000e-06
# Epoch 19/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7235 - loss: 0.6295
# Epoch 19: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.7235 - loss: 0.6294 - val_accuracy: 0.7912 - val_loss: 0.6089 - learning_rate: 5.0000e-06
# Epoch 20/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.7124 - loss: 0.6254
# Epoch 20: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.7124 - loss: 0.6253 - val_accuracy: 0.7390 - val_loss: 0.5878 - learning_rate: 5.0000e-06
# Epoch 21/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7150 - loss: 0.6175
# Epoch 21: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.7150 - loss: 0.6174 - val_accuracy: 0.7912 - val_loss: 0.5800 - learning_rate: 5.0000e-06
# Epoch 22/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.7416 - loss: 0.5955
# Epoch 22: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.7416 - loss: 0.5955 - val_accuracy: 0.7967 - val_loss: 0.5782 - learning_rate: 5.0000e-06
# Epoch 23/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.7375 - loss: 0.5962
# Epoch 23: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.7375 - loss: 0.5962 - val_accuracy: 0.8049 - val_loss: 0.5596 - learning_rate: 5.0000e-06
# Epoch 24/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7589 - loss: 0.5782
# Epoch 24: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 30s 229ms/step - accuracy: 0.7588 - loss: 0.5782 - val_accuracy: 0.7995 - val_loss: 0.5594 - learning_rate: 5.0000e-06
# Epoch 25/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7348 - loss: 0.5770
# Epoch 25: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 258ms/step - accuracy: 0.7349 - loss: 0.5769 - val_accuracy: 0.7967 - val_loss: 0.5453 - learning_rate: 5.0000e-06
# Epoch 26/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7695 - loss: 0.5619
# Epoch 26: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 257ms/step - accuracy: 0.7695 - loss: 0.5619 - val_accuracy: 0.8077 - val_loss: 0.5305 - learning_rate: 5.0000e-06
# Epoch 27/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7714 - loss: 0.5479
# Epoch 27: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 28s 211ms/step - accuracy: 0.7714 - loss: 0.5478 - val_accuracy: 0.8159 - val_loss: 0.5190 - learning_rate: 5.0000e-06
# Epoch 28/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7839 - loss: 0.5293
# Epoch 28: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.7838 - loss: 0.5293 - val_accuracy: 0.8187 - val_loss: 0.4996 - learning_rate: 5.0000e-06
# Epoch 29/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.7986 - loss: 0.5198
# Epoch 29: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.7986 - loss: 0.5198 - val_accuracy: 0.7940 - val_loss: 0.5268 - learning_rate: 5.0000e-06
# Epoch 30/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7870 - loss: 0.5172
# Epoch 30: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.7870 - loss: 0.5172 - val_accuracy: 0.8242 - val_loss: 0.4802 - learning_rate: 5.0000e-06
# Epoch 31/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8027 - loss: 0.5026
# Epoch 31: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.8027 - loss: 0.5026 - val_accuracy: 0.8132 - val_loss: 0.4862 - learning_rate: 5.0000e-06
# Epoch 32/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8193 - loss: 0.4989
# Epoch 32: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.8192 - loss: 0.4989 - val_accuracy: 0.8297 - val_loss: 0.4702 - learning_rate: 5.0000e-06
# Epoch 33/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8286 - loss: 0.4842
# Epoch 33: val_accuracy did not improve from 0.84066
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8285 - loss: 0.4842 - val_accuracy: 0.8324 - val_loss: 0.4673 - learning_rate: 5.0000e-06
# Epoch 34/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8368 - loss: 0.4736
# Epoch 34: val_accuracy improved from 0.84066 to 0.85165, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.8367 - loss: 0.4736 - val_accuracy: 0.8516 - val_loss: 0.4330 - learning_rate: 5.0000e-06
# Epoch 35/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8198 - loss: 0.4716
# Epoch 35: val_accuracy improved from 0.85165 to 0.85440, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.8198 - loss: 0.4716 - val_accuracy: 0.8544 - val_loss: 0.4268 - learning_rate: 5.0000e-06
# Epoch 36/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8312 - loss: 0.4623
# Epoch 36: val_accuracy did not improve from 0.85440
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.8312 - loss: 0.4622 - val_accuracy: 0.8352 - val_loss: 0.4312 - learning_rate: 5.0000e-06
# Epoch 37/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8515 - loss: 0.4321
# Epoch 37: val_accuracy did not improve from 0.85440
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.8514 - loss: 0.4322 - val_accuracy: 0.8242 - val_loss: 0.4550 - learning_rate: 5.0000e-06
# Epoch 38/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8229 - loss: 0.4443
# Epoch 38: val_accuracy did not improve from 0.85440
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8230 - loss: 0.4443 - val_accuracy: 0.8407 - val_loss: 0.4171 - learning_rate: 5.0000e-06
# Epoch 39/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8302 - loss: 0.4389
# Epoch 39: val_accuracy did not improve from 0.85440
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8301 - loss: 0.4389 - val_accuracy: 0.8462 - val_loss: 0.4156 - learning_rate: 5.0000e-06
# Epoch 40/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8299 - loss: 0.4268
# Epoch 40: val_accuracy improved from 0.85440 to 0.85989, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8299 - loss: 0.4268 - val_accuracy: 0.8599 - val_loss: 0.3909 - learning_rate: 5.0000e-06
# Epoch 41/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8395 - loss: 0.4168
# Epoch 41: val_accuracy did not improve from 0.85989
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8395 - loss: 0.4168 - val_accuracy: 0.8462 - val_loss: 0.3942 - learning_rate: 5.0000e-06
# Epoch 42/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8581 - loss: 0.4062
# Epoch 42: val_accuracy did not improve from 0.85989
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.8581 - loss: 0.4062 - val_accuracy: 0.8462 - val_loss: 0.3884 - learning_rate: 5.0000e-06
# Epoch 43/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8567 - loss: 0.3914
# Epoch 43: val_accuracy did not improve from 0.85989
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8566 - loss: 0.3915 - val_accuracy: 0.8599 - val_loss: 0.3717 - learning_rate: 5.0000e-06
# Epoch 44/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8448 - loss: 0.4050
# Epoch 44: val_accuracy did not improve from 0.85989
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8447 - loss: 0.4050 - val_accuracy: 0.8599 - val_loss: 0.3602 - learning_rate: 5.0000e-06
# Epoch 45/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8455 - loss: 0.3967
# Epoch 45: val_accuracy improved from 0.85989 to 0.86264, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8454 - loss: 0.3967 - val_accuracy: 0.8626 - val_loss: 0.3601 - learning_rate: 5.0000e-06
# Epoch 46/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8440 - loss: 0.3989
# Epoch 46: val_accuracy improved from 0.86264 to 0.86538, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8440 - loss: 0.3988 - val_accuracy: 0.8654 - val_loss: 0.3506 - learning_rate: 5.0000e-06
# Epoch 47/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8583 - loss: 0.3760
# Epoch 47: val_accuracy did not improve from 0.86538
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8582 - loss: 0.3760 - val_accuracy: 0.8654 - val_loss: 0.3460 - learning_rate: 5.0000e-06
# Epoch 48/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8534 - loss: 0.3929
# Epoch 48: val_accuracy improved from 0.86538 to 0.86813, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8534 - loss: 0.3929 - val_accuracy: 0.8681 - val_loss: 0.3385 - learning_rate: 5.0000e-06
# Epoch 49/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8569 - loss: 0.3710
# Epoch 49: val_accuracy did not improve from 0.86813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8569 - loss: 0.3711 - val_accuracy: 0.8599 - val_loss: 0.3477 - learning_rate: 5.0000e-06
# Epoch 50/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8710 - loss: 0.3605
# Epoch 50: val_accuracy did not improve from 0.86813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8709 - loss: 0.3605 - val_accuracy: 0.8516 - val_loss: 0.3558 - learning_rate: 5.0000e-06
# Epoch 51/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8493 - loss: 0.3743
# Epoch 51: val_accuracy did not improve from 0.86813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8493 - loss: 0.3743 - val_accuracy: 0.8626 - val_loss: 0.3398 - learning_rate: 5.0000e-06
# Epoch 52/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8769 - loss: 0.3486
# Epoch 52: val_accuracy did not improve from 0.86813
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8768 - loss: 0.3487 - val_accuracy: 0.8324 - val_loss: 0.4029 - learning_rate: 5.0000e-06
# Epoch 53/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8753 - loss: 0.3557
# Epoch 53: val_accuracy improved from 0.86813 to 0.87637, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8752 - loss: 0.3557 - val_accuracy: 0.8764 - val_loss: 0.3265 - learning_rate: 5.0000e-06
# Epoch 54/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8648 - loss: 0.3552
# Epoch 54: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8648 - loss: 0.3553 - val_accuracy: 0.8764 - val_loss: 0.3216 - learning_rate: 5.0000e-06
# Epoch 55/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8737 - loss: 0.3451
# Epoch 55: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8737 - loss: 0.3452 - val_accuracy: 0.8736 - val_loss: 0.3185 - learning_rate: 5.0000e-06
# Epoch 56/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8634 - loss: 0.3533
# Epoch 56: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8634 - loss: 0.3533 - val_accuracy: 0.8544 - val_loss: 0.3424 - learning_rate: 5.0000e-06
# Epoch 57/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8546 - loss: 0.3542
# Epoch 57: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8546 - loss: 0.3542 - val_accuracy: 0.8736 - val_loss: 0.3144 - learning_rate: 5.0000e-06
# Epoch 58/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8824 - loss: 0.3388
# Epoch 58: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8823 - loss: 0.3389 - val_accuracy: 0.8599 - val_loss: 0.3210 - learning_rate: 5.0000e-06
# Epoch 59/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8854 - loss: 0.3211
# Epoch 59: val_accuracy did not improve from 0.87637
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8854 - loss: 0.3212 - val_accuracy: 0.8709 - val_loss: 0.3093 - learning_rate: 5.0000e-06
# Epoch 60/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8801 - loss: 0.3320
# Epoch 60: val_accuracy improved from 0.87637 to 0.88462, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8800 - loss: 0.3321 - val_accuracy: 0.8846 - val_loss: 0.3038 - learning_rate: 5.0000e-06
# Epoch 61/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8605 - loss: 0.3495
# Epoch 61: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8605 - loss: 0.3495 - val_accuracy: 0.8681 - val_loss: 0.3097 - learning_rate: 5.0000e-06
# Epoch 62/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8663 - loss: 0.3536
# Epoch 62: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8663 - loss: 0.3535 - val_accuracy: 0.8654 - val_loss: 0.3168 - learning_rate: 5.0000e-06
# Epoch 63/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8800 - loss: 0.3164
# Epoch 63: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8799 - loss: 0.3165 - val_accuracy: 0.8599 - val_loss: 0.3203 - learning_rate: 5.0000e-06
# Epoch 64/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8750 - loss: 0.3238
# Epoch 64: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8749 - loss: 0.3239 - val_accuracy: 0.8819 - val_loss: 0.2973 - learning_rate: 5.0000e-06
# Epoch 65/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8697 - loss: 0.3280
# Epoch 65: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8697 - loss: 0.3280 - val_accuracy: 0.8681 - val_loss: 0.3012 - learning_rate: 5.0000e-06
# Epoch 66/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8891 - loss: 0.3170
# Epoch 66: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8890 - loss: 0.3170 - val_accuracy: 0.8764 - val_loss: 0.2965 - learning_rate: 5.0000e-06
# Epoch 67/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8739 - loss: 0.3159
# Epoch 67: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8738 - loss: 0.3159 - val_accuracy: 0.8654 - val_loss: 0.3023 - learning_rate: 5.0000e-06
# Epoch 68/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8861 - loss: 0.2950
# Epoch 68: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8861 - loss: 0.2953 - val_accuracy: 0.8626 - val_loss: 0.3229 - learning_rate: 5.0000e-06
# Epoch 69/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8906 - loss: 0.2946
# Epoch 69: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.8905 - loss: 0.2947 - val_accuracy: 0.8626 - val_loss: 0.3160 - learning_rate: 5.0000e-06
# Epoch 70/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8637 - loss: 0.3351
# Epoch 70: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8638 - loss: 0.3351 - val_accuracy: 0.8626 - val_loss: 0.3019 - learning_rate: 5.0000e-06
# Epoch 71/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8964 - loss: 0.2993
# Epoch 71: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8963 - loss: 0.2994 - val_accuracy: 0.8736 - val_loss: 0.2901 - learning_rate: 5.0000e-06
# Epoch 72/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8922 - loss: 0.3082
# Epoch 72: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8922 - loss: 0.3083 - val_accuracy: 0.8654 - val_loss: 0.2962 - learning_rate: 5.0000e-06
# Epoch 73/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8831 - loss: 0.3046
# Epoch 73: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8831 - loss: 0.3046 - val_accuracy: 0.8654 - val_loss: 0.3088 - learning_rate: 5.0000e-06
# Epoch 74/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8822 - loss: 0.3140
# Epoch 74: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8822 - loss: 0.3139 - val_accuracy: 0.8709 - val_loss: 0.2963 - learning_rate: 5.0000e-06
# Epoch 75/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8854 - loss: 0.3051
# Epoch 75: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8853 - loss: 0.3051 - val_accuracy: 0.8709 - val_loss: 0.3001 - learning_rate: 5.0000e-06
# Epoch 76/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8954 - loss: 0.2965
# Epoch 76: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 76: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.8953 - loss: 0.2966 - val_accuracy: 0.8681 - val_loss: 0.2961 - learning_rate: 5.0000e-06
# Epoch 77/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8825 - loss: 0.2968
# Epoch 77: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.8825 - loss: 0.2969 - val_accuracy: 0.8709 - val_loss: 0.2986 - learning_rate: 2.5000e-06
# Epoch 78/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9005 - loss: 0.2810
# Epoch 78: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9004 - loss: 0.2811 - val_accuracy: 0.8736 - val_loss: 0.2871 - learning_rate: 2.5000e-06
# Epoch 79/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8900 - loss: 0.2858
# Epoch 79: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8900 - loss: 0.2859 - val_accuracy: 0.8681 - val_loss: 0.2907 - learning_rate: 2.5000e-06
# Epoch 80/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8920 - loss: 0.2949
# Epoch 80: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8920 - loss: 0.2950 - val_accuracy: 0.8736 - val_loss: 0.2830 - learning_rate: 2.5000e-06
# Epoch 81/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8902 - loss: 0.2900
# Epoch 81: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.8902 - loss: 0.2901 - val_accuracy: 0.8709 - val_loss: 0.2831 - learning_rate: 2.5000e-06
# Epoch 82/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8981 - loss: 0.2982
# Epoch 82: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8980 - loss: 0.2982 - val_accuracy: 0.8681 - val_loss: 0.2826 - learning_rate: 2.5000e-06
# Epoch 83/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8849 - loss: 0.2939
# Epoch 83: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8849 - loss: 0.2939 - val_accuracy: 0.8681 - val_loss: 0.2824 - learning_rate: 2.5000e-06
# Epoch 84/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8934 - loss: 0.2846
# Epoch 84: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8934 - loss: 0.2846 - val_accuracy: 0.8819 - val_loss: 0.2758 - learning_rate: 2.5000e-06
# Epoch 85/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8936 - loss: 0.2953
# Epoch 85: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 171ms/step - accuracy: 0.8936 - loss: 0.2953 - val_accuracy: 0.8709 - val_loss: 0.2805 - learning_rate: 2.5000e-06
# Epoch 86/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8924 - loss: 0.2839
# Epoch 86: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8923 - loss: 0.2841 - val_accuracy: 0.8681 - val_loss: 0.2893 - learning_rate: 2.5000e-06
# Epoch 87/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8855 - loss: 0.3003
# Epoch 87: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 170ms/step - accuracy: 0.8855 - loss: 0.3003 - val_accuracy: 0.8764 - val_loss: 0.2775 - learning_rate: 2.5000e-06
# Epoch 88/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8862 - loss: 0.2915
# Epoch 88: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8863 - loss: 0.2915 - val_accuracy: 0.8736 - val_loss: 0.2756 - learning_rate: 2.5000e-06
# Epoch 89/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9049 - loss: 0.2738
# Epoch 89: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.9048 - loss: 0.2740 - val_accuracy: 0.8736 - val_loss: 0.2928 - learning_rate: 2.5000e-06
# Epoch 90/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9059 - loss: 0.2738
# Epoch 90: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.9058 - loss: 0.2739 - val_accuracy: 0.8791 - val_loss: 0.2727 - learning_rate: 2.5000e-06
# Epoch 91/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8952 - loss: 0.2876
# Epoch 91: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8951 - loss: 0.2876 - val_accuracy: 0.8736 - val_loss: 0.2787 - learning_rate: 2.5000e-06
# Epoch 92/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8966 - loss: 0.2835
# Epoch 92: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8965 - loss: 0.2835 - val_accuracy: 0.8819 - val_loss: 0.2712 - learning_rate: 2.5000e-06
# Epoch 93/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9008 - loss: 0.2776
# Epoch 93: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.9007 - loss: 0.2777 - val_accuracy: 0.8791 - val_loss: 0.2712 - learning_rate: 2.5000e-06
# Epoch 94/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8924 - loss: 0.2887
# Epoch 94: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 171ms/step - accuracy: 0.8923 - loss: 0.2887 - val_accuracy: 0.8736 - val_loss: 0.2800 - learning_rate: 2.5000e-06
# Epoch 95/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9091 - loss: 0.2753
# Epoch 95: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 174ms/step - accuracy: 0.9090 - loss: 0.2753 - val_accuracy: 0.8736 - val_loss: 0.2860 - learning_rate: 2.5000e-06
# Epoch 96/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8950 - loss: 0.2889
# Epoch 96: val_accuracy did not improve from 0.88462
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8950 - loss: 0.2888 - val_accuracy: 0.8764 - val_loss: 0.2767 - learning_rate: 2.5000e-06
# Epoch 97/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8898 - loss: 0.2863
# Epoch 97: val_accuracy improved from 0.88462 to 0.88736, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 173ms/step - accuracy: 0.8898 - loss: 0.2863 - val_accuracy: 0.8874 - val_loss: 0.2689 - learning_rate: 2.5000e-06
# Epoch 98/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.8996 - loss: 0.2736
# Epoch 98: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.8995 - loss: 0.2737 - val_accuracy: 0.8819 - val_loss: 0.2749 - learning_rate: 2.5000e-06
# Epoch 99/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8926 - loss: 0.2713
# Epoch 99: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8925 - loss: 0.2714 - val_accuracy: 0.8819 - val_loss: 0.2712 - learning_rate: 2.5000e-06
# Epoch 100/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9043 - loss: 0.2643
# Epoch 100: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9042 - loss: 0.2645 - val_accuracy: 0.8874 - val_loss: 0.2658 - learning_rate: 2.5000e-06
# Epoch 101/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9085 - loss: 0.2585
# Epoch 101: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9084 - loss: 0.2587 - val_accuracy: 0.8819 - val_loss: 0.2728 - learning_rate: 2.5000e-06
# Epoch 102/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8962 - loss: 0.2750
# Epoch 102: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8962 - loss: 0.2750 - val_accuracy: 0.8819 - val_loss: 0.2702 - learning_rate: 2.5000e-06
# Epoch 103/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9009 - loss: 0.2715
# Epoch 103: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9009 - loss: 0.2715 - val_accuracy: 0.8874 - val_loss: 0.2636 - learning_rate: 2.5000e-06
# Epoch 104/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9056 - loss: 0.2684
# Epoch 104: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9055 - loss: 0.2684 - val_accuracy: 0.8819 - val_loss: 0.2720 - learning_rate: 2.5000e-06
# Epoch 105/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9099 - loss: 0.2527
# Epoch 105: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.9098 - loss: 0.2529 - val_accuracy: 0.8764 - val_loss: 0.2754 - learning_rate: 2.5000e-06
# Epoch 106/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9020 - loss: 0.2729
# Epoch 106: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9019 - loss: 0.2729 - val_accuracy: 0.8791 - val_loss: 0.2732 - learning_rate: 2.5000e-06
# Epoch 107/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9064 - loss: 0.2585
# Epoch 107: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9063 - loss: 0.2586 - val_accuracy: 0.8819 - val_loss: 0.2707 - learning_rate: 2.5000e-06
# Epoch 108/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9061 - loss: 0.2637
# Epoch 108: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
#
# Epoch 108: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9060 - loss: 0.2638 - val_accuracy: 0.8791 - val_loss: 0.2753 - learning_rate: 2.5000e-06
# Epoch 109/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.8964 - loss: 0.2545
# Epoch 109: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 23s 172ms/step - accuracy: 0.8964 - loss: 0.2546 - val_accuracy: 0.8764 - val_loss: 0.2757 - learning_rate: 1.2500e-06
# Epoch 110/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8996 - loss: 0.2631
# Epoch 110: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8995 - loss: 0.2632 - val_accuracy: 0.8874 - val_loss: 0.2608 - learning_rate: 1.2500e-06
# Epoch 111/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9057 - loss: 0.2640
# Epoch 111: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9056 - loss: 0.2641 - val_accuracy: 0.8846 - val_loss: 0.2660 - learning_rate: 1.2500e-06
# Epoch 112/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8992 - loss: 0.2628
# Epoch 112: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.8991 - loss: 0.2629 - val_accuracy: 0.8874 - val_loss: 0.2641 - learning_rate: 1.2500e-06
# Epoch 113/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9072 - loss: 0.2691
# Epoch 113: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9071 - loss: 0.2691 - val_accuracy: 0.8846 - val_loss: 0.2638 - learning_rate: 1.2500e-06
# Epoch 114/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9079 - loss: 0.2660
# Epoch 114: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9078 - loss: 0.2660 - val_accuracy: 0.8874 - val_loss: 0.2631 - learning_rate: 1.2500e-06
# Epoch 115/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8859 - loss: 0.2788
# Epoch 115: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8860 - loss: 0.2787 - val_accuracy: 0.8846 - val_loss: 0.2593 - learning_rate: 1.2500e-06
# Epoch 116/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9125 - loss: 0.2509
# Epoch 116: val_accuracy did not improve from 0.88736
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9125 - loss: 0.2510 - val_accuracy: 0.8819 - val_loss: 0.2693 - learning_rate: 1.2500e-06
# Epoch 117/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9042 - loss: 0.2641
# Epoch 117: val_accuracy improved from 0.88736 to 0.89011, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9042 - loss: 0.2642 - val_accuracy: 0.8901 - val_loss: 0.2616 - learning_rate: 1.2500e-06
# Epoch 118/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9005 - loss: 0.2594
# Epoch 118: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 41s 163ms/step - accuracy: 0.9004 - loss: 0.2594 - val_accuracy: 0.8874 - val_loss: 0.2595 - learning_rate: 1.2500e-06
# Epoch 119/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9052 - loss: 0.2655
# Epoch 119: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9052 - loss: 0.2655 - val_accuracy: 0.8874 - val_loss: 0.2622 - learning_rate: 1.2500e-06
# Epoch 120/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9115 - loss: 0.2601
# Epoch 120: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 120: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9114 - loss: 0.2602 - val_accuracy: 0.8901 - val_loss: 0.2600 - learning_rate: 1.2500e-06
# Epoch 121/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9023 - loss: 0.2650
# Epoch 121: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.9024 - loss: 0.2650 - val_accuracy: 0.8846 - val_loss: 0.2646 - learning_rate: 1.0000e-06
# Epoch 122/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8994 - loss: 0.2578
# Epoch 122: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.8994 - loss: 0.2579 - val_accuracy: 0.8819 - val_loss: 0.2707 - learning_rate: 1.0000e-06
# Epoch 123/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9084 - loss: 0.2624
# Epoch 123: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9083 - loss: 0.2625 - val_accuracy: 0.8819 - val_loss: 0.2635 - learning_rate: 1.0000e-06
# Epoch 124/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9093 - loss: 0.2554
# Epoch 124: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 169ms/step - accuracy: 0.9092 - loss: 0.2555 - val_accuracy: 0.8874 - val_loss: 0.2603 - learning_rate: 1.0000e-06
# Epoch 125/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9027 - loss: 0.2652
# Epoch 125: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9027 - loss: 0.2652 - val_accuracy: 0.8819 - val_loss: 0.2635 - learning_rate: 1.0000e-06
# Epoch 126/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9122 - loss: 0.2532
# Epoch 126: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9121 - loss: 0.2533 - val_accuracy: 0.8846 - val_loss: 0.2612 - learning_rate: 1.0000e-06
# Epoch 127/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9017 - loss: 0.2603
# Epoch 127: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9017 - loss: 0.2603 - val_accuracy: 0.8901 - val_loss: 0.2586 - learning_rate: 1.0000e-06
# Epoch 128/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8891 - loss: 0.2950
# Epoch 128: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.8892 - loss: 0.2948 - val_accuracy: 0.8901 - val_loss: 0.2569 - learning_rate: 1.0000e-06
# Epoch 129/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9132 - loss: 0.2530
# Epoch 129: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9131 - loss: 0.2532 - val_accuracy: 0.8874 - val_loss: 0.2629 - learning_rate: 1.0000e-06
# Epoch 130/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9120 - loss: 0.2596
# Epoch 130: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9119 - loss: 0.2596 - val_accuracy: 0.8846 - val_loss: 0.2629 - learning_rate: 1.0000e-06
# Epoch 131/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9072 - loss: 0.2581
# Epoch 131: val_accuracy did not improve from 0.89011
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9071 - loss: 0.2582 - val_accuracy: 0.8874 - val_loss: 0.2621 - learning_rate: 1.0000e-06
# Epoch 132/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9106 - loss: 0.2671
# ...
# Epoch 152: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 168ms/step - accuracy: 0.9129 - loss: 0.2425 - val_accuracy: 0.8846 - val_loss: 0.2611 - learning_rate: 1.0000e-06
# Epoch 153/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9054 - loss: 0.2510
# Epoch 153: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9054 - loss: 0.2511 - val_accuracy: 0.8874 - val_loss: 0.2585 - learning_rate: 1.0000e-06
# Epoch 154/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9101 - loss: 0.2399
# Epoch 154: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9100 - loss: 0.2401 - val_accuracy: 0.8874 - val_loss: 0.2596 - learning_rate: 1.0000e-06
# Epoch 155/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9070 - loss: 0.2414
# Epoch 155: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9069 - loss: 0.2416 - val_accuracy: 0.8901 - val_loss: 0.2568 - learning_rate: 1.0000e-06
# Epoch 156/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9035 - loss: 0.2617
# Epoch 156: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9035 - loss: 0.2617 - val_accuracy: 0.8874 - val_loss: 0.2610 - learning_rate: 1.0000e-06
# Epoch 157/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9213 - loss: 0.2349
# Epoch 157: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9212 - loss: 0.2351 - val_accuracy: 0.8874 - val_loss: 0.2643 - learning_rate: 1.0000e-06
# Epoch 158/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9092 - loss: 0.2554
# Epoch 158: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 167ms/step - accuracy: 0.9092 - loss: 0.2554 - val_accuracy: 0.8901 - val_loss: 0.2558 - learning_rate: 1.0000e-06
# Epoch 159/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9078 - loss: 0.2592
# Epoch 159: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 24s 186ms/step - accuracy: 0.9078 - loss: 0.2592 - val_accuracy: 0.8956 - val_loss: 0.2533 - learning_rate: 1.0000e-06
# Epoch 160/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.9113 - loss: 0.2532
# Epoch 160: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 261ms/step - accuracy: 0.9113 - loss: 0.2532 - val_accuracy: 0.8874 - val_loss: 0.2505 - learning_rate: 1.0000e-06
# Epoch 161/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.9117 - loss: 0.2548
# Epoch 161: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 258ms/step - accuracy: 0.9117 - loss: 0.2548 - val_accuracy: 0.8929 - val_loss: 0.2521 - learning_rate: 1.0000e-06
# Epoch 162/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9091 - loss: 0.2509
# Epoch 162: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 259ms/step - accuracy: 0.9091 - loss: 0.2509 - val_accuracy: 0.8846 - val_loss: 0.2497 - learning_rate: 1.0000e-06
# Epoch 163/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9132 - loss: 0.2559
# Epoch 163: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 29s 222ms/step - accuracy: 0.9131 - loss: 0.2560 - val_accuracy: 0.8874 - val_loss: 0.2499 - learning_rate: 1.0000e-06
# Epoch 164/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9171 - loss: 0.2319
# Epoch 164: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 260ms/step - accuracy: 0.9170 - loss: 0.2320 - val_accuracy: 0.8901 - val_loss: 0.2559 - learning_rate: 1.0000e-06
# Epoch 165/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9130 - loss: 0.2415
# Epoch 165: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 34s 258ms/step - accuracy: 0.9129 - loss: 0.2416 - val_accuracy: 0.8901 - val_loss: 0.2489 - learning_rate: 1.0000e-06
# Epoch 166/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9101 - loss: 0.2587
# Epoch 166: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9101 - loss: 0.2587 - val_accuracy: 0.8956 - val_loss: 0.2516 - learning_rate: 1.0000e-06
# Epoch 167/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9148 - loss: 0.2453
# Epoch 167: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9148 - loss: 0.2454 - val_accuracy: 0.8929 - val_loss: 0.2558 - learning_rate: 1.0000e-06
# Epoch 168/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9158 - loss: 0.2381
# Epoch 168: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9158 - loss: 0.2382 - val_accuracy: 0.8901 - val_loss: 0.2509 - learning_rate: 1.0000e-06
# Epoch 169/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9157 - loss: 0.2424
# Epoch 169: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9157 - loss: 0.2425 - val_accuracy: 0.8874 - val_loss: 0.2536 - learning_rate: 1.0000e-06
# Epoch 170/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8903 - loss: 0.2597
# Epoch 170: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8904 - loss: 0.2596 - val_accuracy: 0.8901 - val_loss: 0.2482 - learning_rate: 1.0000e-06
# Epoch 171/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9050 - loss: 0.2495
# Epoch 171: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9050 - loss: 0.2494 - val_accuracy: 0.8846 - val_loss: 0.2477 - learning_rate: 1.0000e-06
# Epoch 172/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9042 - loss: 0.2525
# Epoch 172: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9042 - loss: 0.2524 - val_accuracy: 0.8901 - val_loss: 0.2541 - learning_rate: 1.0000e-06
# Epoch 173/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9106 - loss: 0.2570
# Epoch 173: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9105 - loss: 0.2569 - val_accuracy: 0.8901 - val_loss: 0.2458 - learning_rate: 1.0000e-06
# Epoch 174/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9039 - loss: 0.2571
# Epoch 174: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9039 - loss: 0.2571 - val_accuracy: 0.8901 - val_loss: 0.2554 - learning_rate: 1.0000e-06
# Epoch 175/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9107 - loss: 0.2374
# Epoch 175: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9107 - loss: 0.2375 - val_accuracy: 0.8874 - val_loss: 0.2486 - learning_rate: 1.0000e-06
# Epoch 176/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8986 - loss: 0.2503
# Epoch 176: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.8987 - loss: 0.2503 - val_accuracy: 0.8901 - val_loss: 0.2468 - learning_rate: 1.0000e-06
# Epoch 177/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9114 - loss: 0.2541
# Epoch 177: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9114 - loss: 0.2540 - val_accuracy: 0.8901 - val_loss: 0.2481 - learning_rate: 1.0000e-06
# Epoch 178/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9135 - loss: 0.2538
# Epoch 178: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9135 - loss: 0.2537 - val_accuracy: 0.8901 - val_loss: 0.2513 - learning_rate: 1.0000e-06
# Epoch 179/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9120 - loss: 0.2372
# Epoch 179: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9120 - loss: 0.2373 - val_accuracy: 0.8901 - val_loss: 0.2486 - learning_rate: 1.0000e-06
# Epoch 180/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9114 - loss: 0.2386
# Epoch 180: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9114 - loss: 0.2387 - val_accuracy: 0.8929 - val_loss: 0.2585 - learning_rate: 1.0000e-06
# Epoch 181/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9070 - loss: 0.2490
# Epoch 181: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9071 - loss: 0.2490 - val_accuracy: 0.8901 - val_loss: 0.2481 - learning_rate: 1.0000e-06
# Epoch 182/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9070 - loss: 0.2449
# Epoch 182: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9070 - loss: 0.2449 - val_accuracy: 0.8929 - val_loss: 0.2480 - learning_rate: 1.0000e-06
# Epoch 183/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9154 - loss: 0.2364
# Epoch 183: val_accuracy did not improve from 0.89560
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9153 - loss: 0.2365 - val_accuracy: 0.8901 - val_loss: 0.2516 - learning_rate: 1.0000e-06
# Epoch 184/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9185 - loss: 0.2281
# Epoch 184: val_accuracy improved from 0.89560 to 0.89835, saving model to C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9184 - loss: 0.2283 - val_accuracy: 0.8984 - val_loss: 0.2498 - learning_rate: 1.0000e-06
# Epoch 185/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9145 - loss: 0.2471
# Epoch 185: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9144 - loss: 0.2472 - val_accuracy: 0.8901 - val_loss: 0.2515 - learning_rate: 1.0000e-06
# Epoch 186/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9134 - loss: 0.2424
# Epoch 186: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 163ms/step - accuracy: 0.9134 - loss: 0.2425 - val_accuracy: 0.8929 - val_loss: 0.2493 - learning_rate: 1.0000e-06
# Epoch 187/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9154 - loss: 0.2261
# Epoch 187: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9154 - loss: 0.2263 - val_accuracy: 0.8874 - val_loss: 0.2463 - learning_rate: 1.0000e-06
# Epoch 188/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9110 - loss: 0.2491
# Epoch 188: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9109 - loss: 0.2492 - val_accuracy: 0.8956 - val_loss: 0.2484 - learning_rate: 1.0000e-06
# Epoch 189/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9155 - loss: 0.2322
# Epoch 189: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9154 - loss: 0.2323 - val_accuracy: 0.8901 - val_loss: 0.2439 - learning_rate: 1.0000e-06
# Epoch 190/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9145 - loss: 0.2437
# Epoch 190: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9144 - loss: 0.2437 - val_accuracy: 0.8929 - val_loss: 0.2482 - learning_rate: 1.0000e-06
# Epoch 191/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8936 - loss: 0.2594
# Epoch 191: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.8937 - loss: 0.2593 - val_accuracy: 0.8929 - val_loss: 0.2474 - learning_rate: 1.0000e-06
# Epoch 192/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9171 - loss: 0.2281
# Epoch 192: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9171 - loss: 0.2283 - val_accuracy: 0.8929 - val_loss: 0.2486 - learning_rate: 1.0000e-06
# Epoch 193/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9167 - loss: 0.2347
# Epoch 193: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9166 - loss: 0.2348 - val_accuracy: 0.8929 - val_loss: 0.2479 - learning_rate: 1.0000e-06
# Epoch 194/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.9206 - loss: 0.2301
# Epoch 194: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9205 - loss: 0.2302 - val_accuracy: 0.8929 - val_loss: 0.2450 - learning_rate: 1.0000e-06
# Epoch 195/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9199 - loss: 0.2222
# Epoch 195: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9198 - loss: 0.2224 - val_accuracy: 0.8901 - val_loss: 0.2528 - learning_rate: 1.0000e-06
# Epoch 196/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9248 - loss: 0.2252
# Epoch 196: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9247 - loss: 0.2253 - val_accuracy: 0.8901 - val_loss: 0.2498 - learning_rate: 1.0000e-06
# Epoch 197/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9037 - loss: 0.2373
# Epoch 197: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9037 - loss: 0.2374 - val_accuracy: 0.8929 - val_loss: 0.2493 - learning_rate: 1.0000e-06
# Epoch 198/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9267 - loss: 0.2281
# Epoch 198: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9266 - loss: 0.2282 - val_accuracy: 0.8901 - val_loss: 0.2503 - learning_rate: 1.0000e-06
# Epoch 199/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9100 - loss: 0.2310
# Epoch 199: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9099 - loss: 0.2311 - val_accuracy: 0.8901 - val_loss: 0.2494 - learning_rate: 1.0000e-06
# Epoch 200/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9088 - loss: 0.2406
# Epoch 200: val_accuracy did not improve from 0.89835
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9088 - loss: 0.2407 - val_accuracy: 0.8929 - val_loss: 0.2436 - learning_rate: 1.0000e-06
# ✅ モデル保存: C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\models_cnn_traj\traj_cnn_20260109-023739.h5
# ✅ 学習曲線保存: C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\output\learning_curve_traj\traj_learning_curve_20260109-023739.png
#
# [Validation] classification_report
#               precision    recall  f1-score   support
#
#       normal     0.9079    0.9200    0.9139       225
#         ivdd     0.8676    0.8489    0.8582       139
#
#     accuracy                         0.8929       364
#    macro avg     0.8878    0.8845    0.8860       364
# weighted avg     0.8925    0.8929    0.8926       364
#
# ✅ 予測CSV保存: C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\output\learning_curve_traj\traj_val_predictions_20260109-023739.csv
# ✅ 混同行列保存: C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\output\learning_curve_traj\traj_cm_20260109-023739.png
