# %%
# -*- coding: utf-8 -*-
"""
各CSV（DLC 3段ヘッダ）の tail_set の全フレーム平均 (x̄_tail, ȳ_tail) を1回だけ算出して固定し、
全キーポイントの x,y を (x - x̄_tail, y - ȳ_tail) に変換した CSV（<元名>_relative.csv）を出力します。
- 3段ヘッダ（scorer/bodypart/(x|y|likelihood)）は維持、likelihood はそのまま。
- ディレクトリ指定なら GLOB_PATTERN に合うCSVを一括処理、ファイル指定ならその1件のみ。
- likelihoodを使って低品質フレームを欠損→補間してから平均を出すことも可能。

★ 使い方:
  1) 「パス指定・設定」欄の PROJECT_ROOT / INPUT_PATH などを環境に合わせて書き換える
  2) そのまま実行（.py or Notebook）
"""

import os
import glob
import numpy as np
import pandas as pd

# =========================
# パス指定・設定（ここを編集）
# =========================
PROJECT_ROOT = r"C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master"
TRAIN_CSV_DIR = os.path.join(PROJECT_ROOT, "data", "train", "train_csv")
EVAL_CSV_DIR  = os.path.join(PROJECT_ROOT, "data", "test",  "eval_csv")

# 処理対象（単一CSV でも ディレクトリでもOK）
INPUT_PATH    = TRAIN_CSV_DIR        # ← 例) eval_csv を処理する。train_csv を処理したい場合は TRAIN_CSV_DIR に変更
GLOB_PATTERN  = "*.csv"             # ディレクトリ指定時の検索パターン

# tail_set 平均の算出時に likelihood < 閾値 を欠損扱いにして補間するか
USE_LIKELIHOOD       = False
MIN_KEEP_LIKELIHOOD  = 0.6

# 既に *_relative.csv が存在するときに上書きするか
OVERWRITE            = False

# =========================
# ユーティリティ
# =========================
def _norm_name(s: str) -> str:
    """小文字化 + 空白/アンダースコア/ハイフン除去（列名の揺れ吸収）"""
    return "".join(ch for ch in s.lower() if ch not in " _-")

def _resolve_tailset_name(all_bodyparts, want="tail set"):
    """bodypart 実名のうち、'tail set' に相当する列名をロバストに取得"""
    norm2orig = {}
    for bp in all_bodyparts:
        k = _norm_name(bp)
        if k not in norm2orig:
            norm2orig[k] = bp
    key = _norm_name(want)
    if key not in norm2orig:
        raise ValueError(f"'tail set' 列が見つかりません。利用可能 bodyparts: {sorted(set(all_bodyparts))}")
    return norm2orig[key]

def _series_from_multi(df, bodypart, coord):
    """
    df: MultiIndex columns (scorer, bodypart, coord)
    coord: "x" or "y" or "likelihood"
    複数 scorer がある場合は最初の列を使用（一般的に1列）。
    """
    sub = df.xs((bodypart, coord), level=[1,2], axis=1)
    if isinstance(sub, pd.DataFrame):
        return sub.iloc[:, 0]
    return sub  # Series

def _assign_to_multi(df, bodypart, coord, values):
    """df の (任意 scorer, 指定 bodypart, 指定 coord) すべてを values で置換。"""
    targets = [col for col in df.columns if col[1] == bodypart and col[2] == coord]
    if not targets:
        raise KeyError(f"列が見つかりません: ({bodypart}, {coord})")
    for col in targets:
        df[col] = values

def collect_csv_paths(inp, pattern):
    if os.path.isfile(inp):
        return [inp]
    elif os.path.isdir(inp):
        return sorted(glob.glob(os.path.join(inp, pattern)))
    else:
        raise FileNotFoundError(f"入力が見つかりません: {inp}")

# =========================
# メイン処理
# =========================
def process_file(path, use_likelihood=True, min_keep_likelihood=0.6, overwrite=False):
    out_path = os.path.splitext(path)[0] + "_relative.csv"
    if (not overwrite) and os.path.exists(out_path):
        print(f"[SKIP] 既に存在: {out_path}")
        return

    # 読み込み（DLC 3段ヘッダ）
    df = pd.read_csv(path, header=[0,1,2], index_col=0)
    bodyparts = [bp for (_, bp, _) in df.columns]
    tail_name = _resolve_tailset_name(bodyparts, want="tail set")

    # tail_set の x,y を取り出す
    tail_x = _series_from_multi(df, tail_name, "x").astype(float)
    tail_y = _series_from_multi(df, tail_name, "y").astype(float)

    # 平均を出す前に、低 likelihood を欠損扱いにして補間（任意）
    if use_likelihood:
        try:
            tail_l = _series_from_multi(df, tail_name, "likelihood").astype(float)
            mask_low = tail_l < float(min_keep_likelihood)
            tx = tail_x.copy(); ty = tail_y.copy()
            tx[mask_low] = np.nan
            ty[mask_low] = np.nan
            tx = tx.interpolate(method="linear", limit_direction="both").bfill().ffill().fillna(0.0)
            ty = ty.interpolate(method="linear", limit_direction="both").bfill().ffill().fillna(0.0)
            mean_tail_x = float(tx.mean())
            mean_tail_y = float(ty.mean())
        except KeyError:
            # likelihood 列が無いCSVは生値平均
            mean_tail_x = float(tail_x.mean())
            mean_tail_y = float(tail_y.mean())
    else:
        mean_tail_x = float(tail_x.mean())
        mean_tail_y = float(tail_y.mean())

    # 相対座標に置換（全 bodypart の x,y から平均を引く）
    df_out = df.copy()
    for bp in sorted(set(bodyparts)):
        x_series = _series_from_multi(df, bp, "x").astype(float)
        y_series = _series_from_multi(df, bp, "y").astype(float)
        _assign_to_multi(df_out, bp, "x", x_series - mean_tail_x)
        _assign_to_multi(df_out, bp, "y", y_series - mean_tail_y)

    # 保存（3段ヘッダのまま）
    df_out.to_csv(out_path, encoding="utf-8-sig")
    print(f"[OK] {os.path.basename(path)} -> {os.path.basename(out_path)}  "
          f"(tail_mean=({mean_tail_x:.3f},{mean_tail_y:.3f}))")

def main():
    paths = collect_csv_paths(INPUT_PATH, GLOB_PATTERN)
    if not paths:
        raise FileNotFoundError(f"CSV が見つかりません: {INPUT_PATH} / pattern={GLOB_PATTERN}")

    print(f"[INFO] 対象 {len(paths)} 件 from: {INPUT_PATH}")
    for p in paths:
        try:
            process_file(
                p,
                use_likelihood=USE_LIKELIHOOD,
                min_keep_likelihood=MIN_KEEP_LIKELIHOOD,
                overwrite=OVERWRITE
            )
        except Exception as e:
            print(f"[ERROR] {p}: {e}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] 対象 158 件 from: C:\kanno\vscode\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\RNN-for-Human-Activity-Recognition-using-2D-Pose-Input-master\data\train\train_csv
# [OK] ivdd1_10DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_10DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(687.208,256.808))
# [OK] ivdd1_11DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_11DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(534.432,388.842))
# [OK] ivdd1_12DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_12DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(711.530,399.533))
# [OK] ivdd1_13DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_13DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(650.311,406.781))
# [OK] ivdd1_14DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_14DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(945.942,458.410))
# [OK] ivdd1_15DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_15DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(435.605,332.975))
# [OK] ivdd1_16DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_16DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(965.610,562.881))
# [OK] ivdd1_17DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_17DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(856.562,285.714))
# [OK] ivdd1_18DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_18DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(912.994,573.988))
# [OK] ivdd1_19DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_19DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(868.318,477.169))
# [OK] ivdd1_1DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_1DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(436.145,205.735))
# [OK] ivdd1_20DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_20DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(945.084,438.451))
# [OK] ivdd1_21DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_21DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(922.896,386.314))
# [OK] ivdd1_22DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_22DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(809.956,417.548))
# [OK] ivdd1_23DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_23DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(819.849,572.718))
# [OK] ivdd1_24DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_24DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(945.644,463.754))
# [OK] ivdd1_25DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_25DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(879.501,375.321))
# [OK] ivdd1_26DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_26DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(954.544,389.355))
# [OK] ivdd1_27DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_27DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(942.388,399.833))
# [OK] ivdd1_2DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_2DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(299.452,421.030))
# [OK] ivdd1_3DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_3DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(531.163,308.919))
# [OK] ivdd1_4DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_4DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(808.025,368.390))
# [OK] ivdd1_5DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_5DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(582.852,330.995))
# [OK] ivdd1_7DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_7DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(627.281,274.604))
# [OK] ivdd1_8DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_8DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(595.783,355.906))
# [OK] ivdd1_9DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_9DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(614.259,228.496))
# [OK] ivdd1_case1DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_case1DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1102.956,434.939))
# [OK] ivdd1_case2DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_case2DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(317.204,231.783))
# [OK] ivdd1_case3DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_case3DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1211.404,499.821))
# [OK] ivdd1_case4DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_case4DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(618.158,351.336))
# [OK] ivdd1_case5DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd1_case5DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(501.179,431.703))
# [OK] ivdd2_10DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_10DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(569.230,349.618))
# [OK] ivdd2_11DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_11DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(607.319,236.708))
# [OK] ivdd2_13DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_13DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(736.213,339.359))
# [OK] ivdd2_14DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_14DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(660.491,289.554))
# [OK] ivdd2_15DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_15DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(626.262,425.661))
# [OK] ivdd2_17DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_17DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(626.803,295.538))
# [OK] ivdd2_18DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_18DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(554.927,360.422))
# [OK] ivdd2_20DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_20DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1024.237,514.173))
# [OK] ivdd2_21DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_21DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(643.134,299.500))
# [OK] ivdd2_22DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_22DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(522.685,304.422))
# [OK] ivdd2_23DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_23DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(937.844,487.614))
# [OK] ivdd2_24DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_24DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(728.281,187.538))
# [OK] ivdd2_25DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_25DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1047.890,468.246))
# [OK] ivdd2_26DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_26DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(636.899,282.164))
# [OK] ivdd2_27DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_27DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(575.831,283.894))
# [OK] ivdd2_28DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_28DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(550.472,360.195))
# [OK] ivdd2_29DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_29DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1022.605,388.985))
# [OK] ivdd2_2DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_2DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(624.953,238.725))
# [OK] ivdd2_30DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_30DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(645.285,378.034))
# [OK] ivdd2_32DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_32DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(628.548,353.071))
# [OK] ivdd2_33DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_33DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1083.619,454.294))
# [OK] ivdd2_35DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_35DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(826.690,444.633))
# [OK] ivdd2_36DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_36DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(672.628,260.211))
# [OK] ivdd2_37DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_37DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(559.153,287.012))
# [OK] ivdd2_38DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_38DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(873.607,399.198))
# [OK] ivdd2_39DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_39DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(885.457,323.076))
# [OK] ivdd2_40DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_40DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(892.311,618.721))
# [OK] ivdd2_41DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_41DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1014.003,480.949))
# [OK] ivdd2_42DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_42DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(995.356,438.994))
# [OK] ivdd2_43DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_43DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(984.584,291.285))
# [OK] ivdd2_44DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_44DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(864.392,214.566))
# [OK] ivdd2_45DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_45DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(981.056,440.982))
# [OK] ivdd2_46DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_46DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(828.648,463.297))
# [OK] ivdd2_47DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_47DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(912.262,476.488))
# [OK] ivdd2_48DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_48DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(923.328,384.884))
# [OK] ivdd2_4DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_4DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(168.754,165.692))
# [OK] ivdd2_5DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_5DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(157.712,121.680))
# [OK] ivdd2_6DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_6DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(184.945,352.492))
# [OK] ivdd2_8DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_8DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(189.350,372.174))
# [OK] ivdd2_9DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_9DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(643.792,354.982))
# [OK] ivdd2_case10DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case10DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(888.792,488.303))
# [OK] ivdd2_case11DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case11DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(950.852,645.168))
# [OK] ivdd2_case1DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case1DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(668.606,331.061))
# [OK] ivdd2_case2DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case2DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(837.981,438.450))
# [OK] ivdd2_case3DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case3DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(908.676,475.268))
# [OK] ivdd2_case4DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case4DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(526.313,310.447))
# [OK] ivdd2_case5DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case5DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(485.887,239.978))
# [OK] ivdd2_case6DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case6DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(237.950,374.219))
# [OK] ivdd2_case7DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case7DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(684.854,234.538))
# [OK] ivdd2_case8DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case8DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(617.887,530.114))
# [OK] ivdd2_case9DLC_resnet50_IvddOct30shuffle1_100000.csv -> ivdd2_case9DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(740.296,570.899))
# [OK] normal_10DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_10DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(680.464,288.897))
# [OK] normal_11DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_11DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(588.680,375.561))
# [OK] normal_12DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_12DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(765.906,316.965))
# [OK] normal_13DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_13DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(475.841,329.169))
# [OK] normal_14DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_14DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(794.095,63.209))
# [OK] normal_16DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_16DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(586.176,166.669))
# [OK] normal_17DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_17DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(570.676,448.906))
# [OK] normal_18DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_18DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(598.332,311.588))
# [OK] normal_19DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_19DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(601.808,243.092))
# [OK] normal_1DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_1DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(693.189,280.073))
# [OK] normal_20DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_20DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(726.837,393.388))
# [OK] normal_21DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_21DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(554.166,431.583))
# [OK] normal_22DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_22DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(675.935,425.203))
# [OK] normal_23DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_23DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(663.618,300.869))
# [OK] normal_26DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_26DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(679.812,376.473))
# [OK] normal_27DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_27DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(703.912,371.779))
# [OK] normal_28DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_28DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(685.305,359.749))
# [OK] normal_29DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_29DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(679.451,348.953))
# [OK] normal_2DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_2DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(518.600,327.385))
# [OK] normal_30DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_30DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(690.378,494.126))
# [OK] normal_31DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_31DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(580.362,443.165))
# [OK] normal_32DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_32DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(553.637,298.350))
# [OK] normal_33DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_33DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(217.931,340.095))
# [OK] normal_34DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_34DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(286.194,316.798))
# [OK] normal_35DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_35DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(357.613,264.737))
# [OK] normal_36DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_36DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(638.633,336.385))
# [OK] normal_37DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_37DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(334.346,262.489))
# [OK] normal_38DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_38DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(373.580,384.505))
# [OK] normal_39DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_39DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(684.606,404.193))
# [OK] normal_3DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_3DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(726.942,401.681))
# [OK] normal_40DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_40DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(549.686,390.843))
# [OK] normal_41DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_41DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(757.398,265.472))
# [OK] normal_42DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_42DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(560.079,392.815))
# [OK] normal_43DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_43DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(749.215,294.964))
# [OK] normal_44DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_44DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(554.149,305.604))
# [OK] normal_45DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_45DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(629.902,382.194))
# [OK] normal_46DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_46DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(632.017,391.271))
# [OK] normal_47DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_47DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(682.336,169.462))
# [OK] normal_48DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_48DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(720.654,308.908))
# [OK] normal_49DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_49DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(504.573,347.722))
# [OK] normal_4DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_4DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(605.374,346.314))
# [OK] normal_50DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_50DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(756.489,300.043))
# [OK] normal_51DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_51DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(481.869,349.033))
# [OK] normal_52DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_52DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(583.456,275.850))
# [OK] normal_53DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_53DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(580.529,342.013))
# [OK] normal_55DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_55DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(639.692,339.837))
# [OK] normal_56DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_56DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(471.615,386.588))
# [OK] normal_57DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_57DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(631.319,424.764))
# [OK] normal_58DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_58DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(310.396,420.081))
# [OK] normal_59DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_59DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(627.638,340.828))
# [OK] normal_5DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_5DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(750.017,348.516))
# [OK] normal_60DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_60DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(424.635,406.743))
# [OK] normal_61DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_61DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(502.701,251.332))
# [OK] normal_63DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_63DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(954.291,700.341))
# [OK] normal_64DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_64DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(918.565,453.372))
# [OK] normal_65DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_65DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(991.953,380.186))
# [OK] normal_66DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_66DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(969.018,390.409))
# [OK] normal_67DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_67DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(801.621,503.412))
# [OK] normal_68DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_68DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1034.209,564.235))
# [OK] normal_69DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_69DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(891.031,543.582))
# [OK] normal_6DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_6DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(583.242,393.276))
# [OK] normal_70DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_70DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(1000.314,587.958))
# [OK] normal_71DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_71DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(979.299,684.460))
# [OK] normal_72DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_72DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(904.697,447.441))
# [OK] normal_73DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_73DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(851.170,401.246))
# [OK] normal_74DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_74DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(813.526,277.976))
# [OK] normal_75DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_75DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(938.961,351.502))
# [OK] normal_76DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_76DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(988.005,678.769))
# [OK] normal_77DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_77DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(980.653,558.381))
# [OK] normal_78DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_78DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(993.550,583.742))
# [OK] normal_79DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_79DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(875.380,346.375))
# [OK] normal_7DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_7DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(762.051,453.950))
# [OK] normal_80DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_80DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(869.038,343.319))
# [OK] normal_81DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_81DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(933.920,556.346))
# [OK] normal_8DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_8DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(621.676,375.528))
# [OK] normal_9DLC_resnet50_IvddOct30shuffle1_100000.csv -> normal_9DLC_resnet50_IvddOct30shuffle1_100000_relative.csv  (tail_mean=(631.413,496.413))
